# %% [markdown]
# # Goal
#
# I'm working with non spatially-referenced images produced from a laser ablation system. Along with the image, the software produces an "align" file of the same name - an xml file that contains the XY center point of each image (coordinates are in microns) and the XY size (in microns) along with any rotation.
#
# I would like to display the images (we typically generate about 1000 images / day) in their correct relative positions and sizes.
#
# The laser has a stage with a cartesian positive XY coordinate system (in microns), and the origin in the SW corner.
#
# Is there a way to either turn the images into georeferenced geotiffs (using the information in the xml file)? So far I have gotten to the step of generating an affine transform for each scanned image based on it's size and center coordinate in microns and rotation metadata. What I don't have is a definition of a custom CRS in WKT. I don't have any experience with the WKt format but it seems like the only way to represent non-Earth CRSs.
#
# Are there any resources for defining a custom CRS in WKT? I know the units are in microns, the center point of my datum, and the height and width of the coordinate reference system.

# %% [markdown]
# ### Matching png paths to metadata paths and extracting the metadata into tabular format

# %%
import pandas as pd
import skimage.io as skio
from pathlib import Path
import xml.etree.ElementTree as et 
import numpy as np
import affine
import os
from osgeo import gdal, osr

def match_png_align(png_file_path, align_file_path):
    """Tests if png and align file IDs are the same."""
    png_lst = str(png_file_path.name).split("_")
    align_lst = str(align_file_path.name).split("_")
    if png_lst[1] == align_lst[1] \
    and png_lst[2] == align_lst[2] \
    and png_lst[3] == align_lst[3] \
    and png_lst[-1][:-4] == align_lst[-1][:-6]:
        return (png_file_path, align_file_path)


def read_transform_inputs_png(meta_path):
    """Reads xml info about the scanned image used to transform coordinates"""
    xtree = et.parse(meta_path)
    root = xtree.getroot()
    center_info = root[0][2].text.split(",")
    size_info = root[0][3].text.split(",")
    extra_info = root[0][0].text.split(";")
    return {"rotation": float(root[0][1].text), 
           "center_x": float(center_info[0]),
           "center_y" : float(center_info[1]),
           "size_x" : float(size_info[0]),
           "size_y" : float(size_info[1]),
           "brightness": float(extra_info[0].split("=")[1]),
           "contrast": float(extra_info[1].split("=")[1]),
           "autoexposure": float(extra_info[2].split("=")[1]),
           "exposuretime": float(extra_info[3].split("=")[1])}

def read_transform_inputs_datum(datum_path):
    parser = et.XMLParser(encoding="utf-8")
    xtree = et.parse(datum_path, parser=parser)
    root = xtree.getroot()
    return {
        "rotation" : float(root[0][0].text),
        "center_x" : float(root[0][1].text.split(",")[0]),
        "center_y" : float(root[0][1].text.split(",")[1]),
        "size_x" : float(root[0][2].text.split(",")[0]),
        "size_y" : float(root[0][2].text.split(",")[1]),
        "focus" : float(root[0][3].text)
    }

# %%
images_p = Path("images/")

align_paths = list(images_p.glob("ScanImage*.Align"))
png_paths = list(images_p.glob("ScanImage*.png"))

matches = []
for a in align_paths:
    for p in png_paths:
        if match_png_align(p, a):
            matches.append((p,a))

image_df = pd.DataFrame(matches, columns=["png","meta"])


image_df = image_df.join(pd.json_normalize(image_df.meta.apply(read_transform_inputs_png)))

image_df['source_shape'] = image_df.png.apply(lambda x: skio.imread(x).shape)

image_df = image_df.join(pd.DataFrame(image_df['source_shape'].tolist(), index=image_df.index, columns=["source_size_y", "source_size_x", "source_size_band"])  )  

datum_im_p = list(images_p.glob("Image_1*"))[0]
datum_align_p = list(images_p.glob("Image_1*"))[1]

# %% [markdown]
# # Defining the transform for each png

# %% [markdown]
# The format for the transfrm is (uperleftx, scalex, skewx, uperlefty, skewy, scaley) and defines how to map pixel coordinates to CRS coordinates. The only thing missing is a custom CRS that is defined from the datum image metadata.

# %% [markdown]
# X and Y pixel resolution of the datum image

# %%
image_df['resolution_x'] = image_df['size_x'] / image_df['source_size_x']
image_df['resolution_y'] = image_df['size_y'] / image_df['source_size_y']

# %% [markdown]
# Since we know the center and size in projection coordinate of each png scan, we can get the upper left.

# %%
image_df['upleftx'] = image_df.center_x - image_df.size_x / 2
image_df['uplefty'] = image_df.center_y - image_df.size_y / 2
# Specify raster location through geotransform array
# (uperleftx, scalex, skewx, uperlefty, skewy, scaley)
image_df["affine_transform"] = image_df.apply(lambda row: affine.Affine(row['upleftx'], row['resolution_x'], row['rotation'], row['uplefty'], row['rotation'], -row['resolution_y']), axis=1)

# %% [markdown]
# According to John, for the datum, we need to find the x and y size AFTER rotation by half a degree, the sizes in the metadata are pre rotation.
#
# The datum info here might not be necessary, except to reference the datum image since it is rotated.

# %%
# for some reason this starts throwing a parse error. pulled the big image size and center out manually, put in georef func
# datum_meta = read_transform_inputs_datum(str(datum_align_p))
# datum_meta

# %% [markdown]
# # Georeferences each png on a cartesian projection (epsg:6507) based on the upper left coordinate in microns, then saves as a geotiff

# %%
def georef(row, outfolder="output"):
    # might need these to define total bounds of the CRS but maybe not
    center_x = 42085.00
    center_y = 47699.00
    size_x = 117207.00
    size_y = 104307.00
    src_filename = str(row["png"])
    
    if os.path.exists(outfolder) == False:
        os.mkdir(outfolder)
    
    dst_filename = os.path.join(outfolder, os.path.basename(str(row['png'])).split(".")[0] + ".tif")
    
    # Opens source dataset
    src_ds = gdal.Open(src_filename)

    driver = gdal.GetDriverByName('GTiff')
    ds = driver.Create(dst_filename, xsize=int(row['source_size_x']), ysize=int(row['source_size_y']), bands=3)

    # this assumes the projection is Geographic lat/lon WGS 84
    srs = osr.SpatialReference()
    srs.ImportFromEPSG(6507)
    ds.SetProjection(srs.ExportToWkt())

    gt = list(row['affine_transform'])[0:6]
    ds.SetGeoTransform(gt)

    outband = ds.GetRasterBand(1)
    arr = skio.imread(src_filename)
    arr = np.moveaxis(arr, -1, 0)
    for i, band in enumerate(arr, 1):
        ds.GetRasterBand(i).WriteArray(band)
        
# georef(image_df.iloc[1])

# %%
image_df.apply(georef, axis=1)
# Out:
# png                 images/ScanImage_W235_14_8_Ablation_EndPattern...
# meta                images/ScanImage_W235_14_8_Ablation_EndPattern...
# rotation                                                            0
# center_x                                                        34495
# center_y                                                        25265
# size_x                                                            550
# size_y                                                            440
# brightness                                                         49
# contrast                                                           70
# autoexposure                                                        1
# exposuretime                                                   123.08
# source_shape                                          (1024, 1280, 3)
# source_size_y                                                    1024
# source_size_x                                                    1280
# source_size_band                                                    3
# resolution_x                                                 0.429688
# resolution_y                                                 0.429688
# upleftx                                                         34220
# uplefty                                                         25045
# affine_transform    (34220.0, 0.4296875, 0.0, 25045.0, 0.0, -0.429...
# Name: 0, dtype: object
# png                 images/ScanImage_KT_04_11_Ablation_EndPattern_...
# meta                images/ScanImage_KT_04_11_Ablation_EndPattern_...
# rotation                                                            0
# center_x                                                      17902.5
# center_y                                                        39021
# size_x                                                            550
# size_y                                                            440
# brightness                                                         49
# contrast                                                           70
# autoexposure                                                        1
# exposuretime                                                   123.08
# source_shape                                          (1024, 1280, 3)
# source_size_y                                                    1024
# source_size_x                                                    1280
# source_size_band                                                    3
# resolution_x                                                 0.429688
# resolution_y                                                 0.429688
# upleftx                                                       17627.5
# uplefty                                                         38801
# affine_transform    (17627.5, 0.4296875, 0.0, 38801.0, 0.0, -0.429...
# Name: 1, dtype: object
# png                 images/ScanImage_W235_10_12_Ablation_EndPatter...
# meta                images/ScanImage_W235_10_12_Ablation_EndPatter...
# rotation                                                            0
# center_x                                                      49390.5
# center_y                                                       3841.5
# size_x                                                            550
# size_y                                                            440
# brightness                                                         49
# contrast                                                           70
# autoexposure                                                        1
# exposuretime                                                   123.08
# source_shape                                          (1024, 1280, 3)
# source_size_y                                                    1024
# source_size_x                                                    1280
# source_size_band                                                    3
# resolution_x                                                 0.429688
# resolution_y                                                 0.429688
# upleftx                                                       49115.5
# uplefty                                                        3621.5
# affine_transform    (49115.5, 0.4296875, 0.0, 3621.5, 0.0, -0.4296...
# Name: 2, dtype: object
# png                 images/ScanImage_W235_1_2_Ablation_EndPattern_...
# meta                images/ScanImage_W235_1_2_Ablation_EndPattern_...
# rotation                                                            0
# center_x                                                        55669
# center_y                                                        40589
# size_x                                                            550
# size_y                                                            440
# brightness                                                         49
# contrast                                                           70
# autoexposure                                                        1
# exposuretime                                                   123.08
# source_shape                                          (1024, 1280, 3)
# source_size_y                                                    1024
# source_size_x                                                    1280
# source_size_band                                                    3
# resolution_x                                                 0.429688
# resolution_y                                                 0.429688
# upleftx                                                         55394
# uplefty                                                         40369
# affine_transform    (55394.0, 0.4296875, 0.0, 40369.0, 0.0, -0.429...
# Name: 3, dtype: object
# png                 images/ScanImage_KT_03_1_Ablation_EndPattern_1...
# meta                images/ScanImage_KT_03_1_Ablation_EndPattern_1...
# rotation                                                            0
# center_x                                                         7817
# center_y                                                        40128
# size_x                                                            550
# size_y                                                            440
# brightness                                                         49
# contrast                                                           70
# autoexposure                                                        1
# exposuretime                                                   123.08
# source_shape                                          (1024, 1280, 3)
# source_size_y                                                    1024
# source_size_x                                                    1280
# source_size_band                                                    3
# resolution_x                                                 0.429688
# resolution_y                                                 0.429688
# upleftx                                                          7542
# uplefty                                                         39908
# affine_transform    (7542.0, 0.4296875, 0.0, 39908.0, 0.0, -0.4296...
# Name: 4, dtype: object
# png                 images/ScanImage_KT_04_2_Ablation_EndPattern_1...
# meta                images/ScanImage_KT_04_2_Ablation_EndPattern_1...
# rotation                                                            0
# center_x                                                        17750
# center_y                                                        38894
# size_x                                                            550
# size_y                                                            440
# brightness                                                         49
# contrast                                                           70
# autoexposure                                                        1
# exposuretime                                                   123.08
# source_shape                                          (1024, 1280, 3)
# source_size_y                                                    1024
# source_size_x                                                    1280
# source_size_band                                                    3
# resolution_x                                                 0.429688
# resolution_y                                                 0.429688
# upleftx                                                         17475
# uplefty                                                         38674
# affine_transform    (17475.0, 0.4296875, 0.0, 38674.0, 0.0, -0.429...
# Name: 5, dtype: object
# png                 images/ScanImage_W235_9_55_Ablation_EndPattern...
# meta                images/ScanImage_W235_9_55_Ablation_EndPattern...
# rotation                                                            0
# center_x                                                      50790.5
# center_y                                                         4130
# size_x                                                            550
# size_y                                                            440
# brightness                                                         49
# contrast                                                           70
# autoexposure                                                        1
# exposuretime                                                   123.08
# source_shape                                          (1024, 1280, 3)
# source_size_y                                                    1024
# source_size_x                                                    1280
# source_size_band                                                    3
# resolution_x                                                 0.429688
# resolution_y                                                 0.429688
# upleftx                                                       50515.5
# uplefty                                                          3910
# affine_transform    (50515.5, 0.4296875, 0.0, 3910.0, 0.0, -0.4296...
# Name: 6, dtype: object
# png                 images/ScanImage_W235_7_31_Ablation_EndPattern...
# meta                images/ScanImage_W235_7_31_Ablation_EndPattern...
# rotation                                                            0
# center_x                                                        50242
# center_y                                                      27744.5
# size_x                                                            550
# size_y                                                            440
# brightness                                                         49
# contrast                                                           70
# autoexposure                                                        1
# exposuretime                                                   123.08
# source_shape                                          (1024, 1280, 3)
# source_size_y                                                    1024
# source_size_x                                                    1280
# source_size_band                                                    3
# resolution_x                                                 0.429688
# resolution_y                                                 0.429688
# upleftx                                                         49967
# uplefty                                                       27524.5
# affine_transform    (49967.0, 0.4296875, 0.0, 27524.5, 0.0, -0.429...
# Name: 7, dtype: object
# png                 images/ScanImage_KT_06_3_Ablation_EndPattern_1...
# meta                images/ScanImage_KT_06_3_Ablation_EndPattern_1...
# rotation                                                            0
# center_x                                                        22071
# center_y                                                        23600
# size_x                                                            550
# size_y                                                            440
# brightness                                                         49
# contrast                                                           70
# autoexposure                                                        1
# exposuretime                                                   123.08
# source_shape                                          (1024, 1280, 3)
# source_size_y                                                    1024
# source_size_x                                                    1280
# source_size_band                                                    3
# resolution_x                                                 0.429688
# resolution_y                                                 0.429688
# upleftx                                                         21796
# uplefty                                                         23380
# affine_transform    (21796.0, 0.4296875, 0.0, 23380.0, 0.0, -0.429...
# Name: 8, dtype: object
# png                 images/ScanImage_AR2_4_11_Ablation_EndPattern_...
# meta                images/ScanImage_AR2_4_11_Ablation_EndPattern_...
# rotation                                                            0
# center_x                                                      49825.5
# center_y                                                      80829.5
# size_x                                                            550
# size_y                                                            440
# brightness                                                         49
# contrast                                                           70
# autoexposure                                                        1
# exposuretime                                                   123.08
# source_shape                                          (1024, 1280, 3)
# source_size_y                                                    1024
# source_size_x                                                    1280
# source_size_band                                                    3
# resolution_x                                                 0.429688
# resolution_y                                                 0.429688
# upleftx                                                       49550.5
# uplefty                                                       80609.5
# affine_transform    (49550.5, 0.4296875, 0.0, 80609.5, 0.0, -0.429...
# Name: 9, dtype: object
# png                 images/ScanImage_W235_2_3_Ablation_EndPattern_...
# meta                images/ScanImage_W235_2_3_Ablation_EndPattern_...
# rotation                                                            0
# center_x                                                      54800.5
# center_y                                                        38116
# size_x                                                            550
# size_y                                                            440
# brightness                                                         49
# contrast                                                           70
# autoexposure                                                        1
# exposuretime                                                   123.08
# source_shape                                          (1024, 1280, 3)
# source_size_y                                                    1024
# source_size_x                                                    1280
# source_size_band                                                    3
# resolution_x                                                 0.429688
# resolution_y                                                 0.429688
# upleftx                                                       54525.5
# uplefty                                                         37896
# affine_transform    (54525.5, 0.4296875, 0.0, 37896.0, 0.0, -0.429...
# Name: 10, dtype: object
# png                 images/ScanImage_AR2_4_6_Ablation_EndPattern_1...
# meta                images/ScanImage_AR2_4_6_Ablation_EndPattern_1...
# rotation                                                            0
# center_x                                                        49769
# center_y                                                        80741
# size_x                                                            550
# size_y                                                            440
# brightness                                                         49
# contrast                                                           70
# autoexposure                                                        1
# exposuretime                                                   123.08
# source_shape                                          (1024, 1280, 3)
# source_size_y                                                    1024
# source_size_x                                                    1280
# source_size_band                                                    3
# resolution_x                                                 0.429688
# resolution_y                                                 0.429688
# upleftx                                                         49494
# uplefty                                                         80521
# affine_transform    (49494.0, 0.4296875, 0.0, 80521.0, 0.0, -0.429...
# Name: 11, dtype: object
# png                 images/ScanImage_W235_14_17_Ablation_EndPatter...
# meta                images/ScanImage_W235_14_17_Ablation_EndPatter...
# rotation                                                            0
# center_x                                                        34609
# center_y                                                        25205
# size_x                                                            550
# size_y                                                            440
# brightness                                                         49
# contrast                                                           70
# autoexposure                                                        1
# exposuretime                                                   123.08
# source_shape                                          (1024, 1280, 3)
# source_size_y                                                    1024
# source_size_x                                                    1280
# source_size_band                                                    3
# resolution_x                                                 0.429688
# resolution_y                                                 0.429688
# upleftx                                                         34334
# uplefty                                                         24985
# affine_transform    (34334.0, 0.4296875, 0.0, 24985.0, 0.0, -0.429...
# Name: 12, dtype: object
# png                 images/ScanImage_KT_07_4_Ablation_EndPattern_1...
# meta                images/ScanImage_KT_07_4_Ablation_EndPattern_1...
# rotation                                                            0
# center_x                                                      21435.5
# center_y                                                        20819
# size_x                                                            550
# size_y                                                            440
# brightness                                                         49
# contrast                                                           70
# autoexposure                                                        1
# exposuretime                                                   123.08
# source_shape                                          (1024, 1280, 3)
# source_size_y                                                    1024
# source_size_x                                                    1280
# source_size_band                                                    3
# resolution_x                                                 0.429688
# resolution_y                                                 0.429688
# upleftx                                                       21160.5
# uplefty                                                         20599
# affine_transform    (21160.5, 0.4296875, 0.0, 20599.0, 0.0, -0.429...
# Name: 13, dtype: object
# png                 images/ScanImage_W235_9_60_Ablation_EndPattern...
# meta                images/ScanImage_W235_9_60_Ablation_EndPattern...
# rotation                                                            0
# center_x                                                        50674
# center_y                                                       4090.5
# size_x                                                            550
# size_y                                                            440
# brightness                                                         49
# contrast                                                           70
# autoexposure                                                        1
# exposuretime                                                   123.08
# source_shape                                          (1024, 1280, 3)
# source_size_y                                                    1024
# source_size_x                                                    1280
# source_size_band                                                    3
# resolution_x                                                 0.429688
# resolution_y                                                 0.429688
# upleftx                                                         50399
# uplefty                                                        3870.5
# affine_transform    (50399.0, 0.4296875, 0.0, 3870.5, 0.0, -0.4296...
# Name: 14, dtype: object
# png                 images/ScanImage_AR2_10_39_Ablation_EndPattern...
# meta                images/ScanImage_AR2_10_39_Ablation_EndPattern...
# rotation                                                            0
# center_x                                                      42994.5
# center_y                                                        67442
# size_x                                                            550
# size_y                                                            440
# brightness                                                         49
# contrast                                                           70
# autoexposure                                                        1
# exposuretime                                                   123.08
# source_shape                                          (1024, 1280, 3)
# source_size_y                                                    1024
# source_size_x                                                    1280
# source_size_band                                                    3
# resolution_x                                                 0.429688
# resolution_y                                                 0.429688
# upleftx                                                       42719.5
# uplefty                                                         67222
# affine_transform    (42719.5, 0.4296875, 0.0, 67222.0, 0.0, -0.429...
# Name: 15, dtype: object
# png                 images/ScanImage_KT_11_33_Ablation_EndPattern_...
# meta                images/ScanImage_KT_11_33_Ablation_EndPattern_...
# rotation                                                            0
# center_x                                                       -482.5
# center_y                                                        28684
# size_x                                                            550
# size_y                                                            440
# brightness                                                         49
# contrast                                                           70
# autoexposure                                                        1
# exposuretime                                                   123.08
# source_shape                                          (1024, 1280, 3)
# source_size_y                                                    1024
# source_size_x                                                    1280
# source_size_band                                                    3
# resolution_x                                                 0.429688
# resolution_y                                                 0.429688
# upleftx                                                        -757.5
# uplefty                                                         28464
# affine_transform    (-757.5, 0.4296875, 0.0, 28464.0, 0.0, -0.4296...
# Name: 16, dtype: object
# png                 images/ScanImage_W235_8_1_Ablation_EndPattern_...
# meta                images/ScanImage_W235_8_1_Ablation_EndPattern_...
# rotation                                                            0
# center_x                                                      55612.5
# center_y                                                        17215
# size_x                                                            550
# size_y                                                            440
# brightness                                                         49
# contrast                                                           70
# autoexposure                                                        1
# exposuretime                                                   123.08
# source_shape                                          (1024, 1280, 3)
# source_size_y                                                    1024
# source_size_x                                                    1280
# source_size_band                                                    3
# resolution_x                                                 0.429688
# resolution_y                                                 0.429688
# upleftx                                                       55337.5
# uplefty                                                         16995
# affine_transform    (55337.5, 0.4296875, 0.0, 16995.0, 0.0, -0.429...
# Name: 17, dtype: object
# png                 images/ScanImage_W235_6_15_Ablation_EndPattern...
# meta                images/ScanImage_W235_6_15_Ablation_EndPattern...
# rotation                                                            0
# center_x                                                      47922.5
# center_y                                                      25830.5
# size_x                                                            550
# size_y                                                            440
# brightness                                                         49
# contrast                                                           70
# autoexposure                                                        1
# exposuretime                                                   123.08
# source_shape                                          (1024, 1280, 3)
# source_size_y                                                    1024
# source_size_x                                                    1280
# source_size_band                                                    3
# resolution_x                                                 0.429688
# resolution_y                                                 0.429688
# upleftx                                                       47647.5
# uplefty                                                       25610.5
# affine_transform    (47647.5, 0.4296875, 0.0, 25610.5, 0.0, -0.429...
# Name: 18, dtype: object
# png                 images/ScanImage_AR2_6_50_Ablation_EndPattern_...
# meta                images/ScanImage_AR2_6_50_Ablation_EndPattern_...
# rotation                                                            0
# center_x                                                      54667.5
# center_y                                                        67906
# size_x                                                            550
# size_y                                                            440
# brightness                                                         49
# contrast                                                           70
# autoexposure                                                        1
# exposuretime                                                   123.08
# source_shape                                          (1024, 1280, 3)
# source_size_y                                                    1024
# source_size_x                                                    1280
# source_size_band                                                    3
# resolution_x                                                 0.429688
# resolution_y                                                 0.429688
# upleftx                                                       54392.5
# uplefty                                                         67686
# affine_transform    (54392.5, 0.4296875, 0.0, 67686.0, 0.0, -0.429...
# Name: 19, dtype: object
# png                 images/ScanImage_AR2_4_8_Ablation_EndPattern_1...
# meta                images/ScanImage_AR2_4_8_Ablation_EndPattern_1...
# rotation                                                            0
# center_x                                                        49934
# center_y                                                      80830.5
# size_x                                                            550
# size_y                                                            440
# brightness                                                         49
# contrast                                                           70
# autoexposure                                                        1
# exposuretime                                                   123.08
# source_shape                                          (1024, 1280, 3)
# source_size_y                                                    1024
# source_size_x                                                    1280
# source_size_band                                                    3
# resolution_x                                                 0.429688
# resolution_y                                                 0.429688
# upleftx                                                         49659
# uplefty                                                       80610.5
# affine_transform    (49659.0, 0.4296875, 0.0, 80610.5, 0.0, -0.429...
# Name: 20, dtype: object
# png                 images/ScanImage_KT_05_5_Ablation_EndPattern_1...
# meta                images/ScanImage_KT_05_5_Ablation_EndPattern_1...
# rotation                                                            0
# center_x                                                        13796
# center_y                                                        33934
# size_x                                                            550
# size_y                                                            440
# brightness                                                         49
# contrast                                                           70
# autoexposure                                                        1
# exposuretime                                                   123.08
# source_shape                                          (1024, 1280, 3)
# source_size_y                                                    1024
# source_size_x                                                    1280
# source_size_band                                                    3
# resolution_x                                                 0.429688
# resolution_y                                                 0.429688
# upleftx                                                         13521
# uplefty                                                         33714
# affine_transform    (13521.0, 0.4296875, 0.0, 33714.0, 0.0, -0.429...
# Name: 21, dtype: object
# png                 images/ScanImage_W235_10_42_Ablation_EndPatter...
# meta                images/ScanImage_W235_10_42_Ablation_EndPatter...
# rotation                                                            0
# center_x                                                      47462.5
# center_y                                                       3257.5
# size_x                                                            550
# size_y                                                            440
# brightness                                                         49
# contrast                                                           70
# autoexposure                                                        1
# exposuretime                                                   123.08
# source_shape                                          (1024, 1280, 3)
# source_size_y                                                    1024
# source_size_x                                                    1280
# source_size_band                                                    3
# resolution_x                                                 0.429688
# resolution_y                                                 0.429688
# upleftx                                                       47187.5
# uplefty                                                        3037.5
# affine_transform    (47187.5, 0.4296875, 0.0, 3037.5, 0.0, -0.4296...
# Name: 22, dtype: object
# png                 images/ScanImage_AR2_4_31_Ablation_EndPattern_...
# meta                images/ScanImage_AR2_4_31_Ablation_EndPattern_...
# rotation                                                            0
# center_x                                                        52248
# center_y                                                        81105
# size_x                                                            550
# size_y                                                            440
# brightness                                                         49
# contrast                                                           70
# autoexposure                                                        1
# exposuretime                                                   123.08
# source_shape                                          (1024, 1280, 3)
# source_size_y                                                    1024
# source_size_x                                                    1280
# source_size_band                                                    3
# resolution_x                                                 0.429688
# resolution_y                                                 0.429688
# upleftx                                                         51973
# uplefty                                                         80885
# affine_transform    (51973.0, 0.4296875, 0.0, 80885.0, 0.0, -0.429...
# Name: 23, dtype: object
# png                 images/ScanImage_W235_6_18_Ablation_EndPattern...
# meta                images/ScanImage_W235_6_18_Ablation_EndPattern...
# rotation                                                            0
# center_x                                                        47981
# center_y                                                      25724.5
# size_x                                                            550
# size_y                                                            440
# brightness                                                         49
# contrast                                                           70
# autoexposure                                                        1
# exposuretime                                                   123.08
# source_shape                                          (1024, 1280, 3)
# source_size_y                                                    1024
# source_size_x                                                    1280
# source_size_band                                                    3
# resolution_x                                                 0.429688
# resolution_y                                                 0.429688
# upleftx                                                         47706
# uplefty                                                       25504.5
# affine_transform    (47706.0, 0.4296875, 0.0, 25504.5, 0.0, -0.429...
# Name: 24, dtype: object
# png                 images/ScanImage_AR2_10_5_Ablation_EndPattern_...
# meta                images/ScanImage_AR2_10_5_Ablation_EndPattern_...
# rotation                                                            0
# center_x                                                        42880
# center_y                                                        67929
# size_x                                                            550
# size_y                                                            440
# brightness                                                         49
# contrast                                                           70
# autoexposure                                                        1
# exposuretime                                                   123.08
# source_shape                                          (1024, 1280, 3)
# source_size_y                                                    1024
# source_size_x                                                    1280
# source_size_band                                                    3
# resolution_x                                                 0.429688
# resolution_y                                                 0.429688
# upleftx                                                         42605
# uplefty                                                         67709
# affine_transform    (42605.0, 0.4296875, 0.0, 67709.0, 0.0, -0.429...
# Name: 25, dtype: object
# png                 images/ScanImage_W235_8_8_Ablation_EndPattern_...
# meta                images/ScanImage_W235_8_8_Ablation_EndPattern_...
# rotation                                                            0
# center_x                                                        55545
# center_y                                                      17075.5
# size_x                                                            550
# size_y                                                            440
# brightness                                                         49
# contrast                                                           70
# autoexposure                                                        1
# exposuretime                                                   123.08
# source_shape                                          (1024, 1280, 3)
# source_size_y                                                    1024
# source_size_x                                                    1280
# source_size_band                                                    3
# resolution_x                                                 0.429688
# resolution_y                                                 0.429688
# upleftx                                                         55270
# uplefty                                                       16855.5
# affine_transform    (55270.0, 0.4296875, 0.0, 16855.5, 0.0, -0.429...
# Name: 26, dtype: object
# png                 images/ScanImage_W235_11_21_Ablation_EndPatter...
# meta                images/ScanImage_W235_11_21_Ablation_EndPatter...
# rotation                                                            0
# center_x                                                      41501.5
# center_y                                                         6617
# size_x                                                            550
# size_y                                                            440
# brightness                                                         49
# contrast                                                           70
# autoexposure                                                        1
# exposuretime                                                   123.08
# source_shape                                          (1024, 1280, 3)
# source_size_y                                                    1024
# source_size_x                                                    1280
# source_size_band                                                    3
# resolution_x                                                 0.429688
# resolution_y                                                 0.429688
# upleftx                                                       41226.5
# uplefty                                                          6397
# affine_transform    (41226.5, 0.4296875, 0.0, 6397.0, 0.0, -0.4296...
# Name: 27, dtype: object
# png                 images/ScanImage_AR2_9_9_Ablation_EndPattern_1...
# meta                images/ScanImage_AR2_9_9_Ablation_EndPattern_1...
# rotation                                                            0
# center_x                                                      45287.5
# center_y                                                        65272
# size_x                                                            550
# size_y                                                            440
# brightness                                                         49
# contrast                                                           70
# autoexposure                                                        1
# exposuretime                                                   123.08
# source_shape                                          (1024, 1280, 3)
# source_size_y                                                    1024
# source_size_x                                                    1280
# source_size_band                                                    3
# resolution_x                                                 0.429688
# resolution_y                                                 0.429688
# upleftx                                                       45012.5
# uplefty                                                         65052
# affine_transform    (45012.5, 0.4296875, 0.0, 65052.0, 0.0, -0.429...
# Name: 28, dtype: object
# png                 images/ScanImage_AR2_5_2_Ablation_EndPattern_1...
# meta                images/ScanImage_AR2_5_2_Ablation_EndPattern_1...
# rotation                                                            0
# center_x                                                        51599
# center_y                                                        75995
# size_x                                                            550
# size_y                                                            440
# brightness                                                         49
# contrast                                                           70
# autoexposure                                                        1
# exposuretime                                                   123.08
# source_shape                                          (1024, 1280, 3)
# source_size_y                                                    1024
# source_size_x                                                    1280
# source_size_band                                                    3
# resolution_x                                                 0.429688
# resolution_y                                                 0.429688
# upleftx                                                         51324
# uplefty                                                         75775
# affine_transform    (51324.0, 0.4296875, 0.0, 75775.0, 0.0, -0.429...
# Name: 29, dtype: object
# png                 images/ScanImage_W235_4_11_Ablation_EndPattern...
# meta                images/ScanImage_W235_4_11_Ablation_EndPattern...
# rotation                                                            0
# center_x                                                        42872
# center_y                                                      36324.5
# size_x                                                            550
# size_y                                                            440
# brightness                                                         49
# contrast                                                           70
# autoexposure                                                        1
# exposuretime                                                   123.08
# source_shape                                          (1024, 1280, 3)
# source_size_y                                                    1024
# source_size_x                                                    1280
# source_size_band                                                    3
# resolution_x                                                 0.429688
# resolution_y                                                 0.429688
# upleftx                                                         42597
# uplefty                                                       36104.5
# affine_transform    (42597.0, 0.4296875, 0.0, 36104.5, 0.0, -0.429...
# Name: 30, dtype: object
# png                 images/ScanImage_AR2_6_19_Ablation_EndPattern_...
# meta                images/ScanImage_AR2_6_19_Ablation_EndPattern_...
# rotation                                                            0
# center_x                                                      52789.5
# center_y                                                        65904
# size_x                                                            550
# size_y                                                            440
# brightness                                                         49
# contrast                                                           70
# autoexposure                                                        1
# exposuretime                                                   123.08
# source_shape                                          (1024, 1280, 3)
# source_size_y                                                    1024
# source_size_x                                                    1280
# source_size_band                                                    3
# resolution_x                                                 0.429688
# resolution_y                                                 0.429688
# upleftx                                                       52514.5
# uplefty                                                         65684
# affine_transform    (52514.5, 0.4296875, 0.0, 65684.0, 0.0, -0.429...
# Name: 31, dtype: object
# png                 images/ScanImage_W235_4_12_Ablation_EndPattern...
# meta                images/ScanImage_W235_4_12_Ablation_EndPattern...
# rotation                                                            0
# center_x                                                        42897
# center_y                                                        36300
# size_x                                                            550
# size_y                                                            440
# brightness                                                         49
# contrast                                                           70
# autoexposure                                                        1
# exposuretime                                                   123.08
# source_shape                                          (1024, 1280, 3)
# source_size_y                                                    1024
# source_size_x                                                    1280
# source_size_band                                                    3
# resolution_x                                                 0.429688
# resolution_y                                                 0.429688
# upleftx                                                         42622
# uplefty                                                         36080
# affine_transform    (42622.0, 0.4296875, 0.0, 36080.0, 0.0, -0.429...
# Name: 32, dtype: object
# png                 images/ScanImage_AR2_1_15_Ablation_EndPattern_...
# meta                images/ScanImage_AR2_1_15_Ablation_EndPattern_...
# rotation                                                            0
# center_x                                                      46263.5
# center_y                                                      89625.5
# size_x                                                            550
# size_y                                                            440
# brightness                                                         49
# contrast                                                           70
# autoexposure                                                        1
# exposuretime                                                   123.08
# source_shape                                          (1024, 1280, 3)
# source_size_y                                                    1024
# source_size_x                                                    1280
# ...
# uplefty                                                         84544
# affine_transform    (39810.0, 0.4296875, 0.0, 84544.0, 0.0, -0.429...
# Name: 745, dtype: object
# png                 images/ScanImage_AR2_3_13_Ablation_EndPattern_...
# meta                images/ScanImage_AR2_3_13_Ablation_EndPattern_...
# rotation                                                            0
# center_x                                                      55871.5
# center_y                                                      84864.5
# size_x                                                            550
# size_y                                                            440
# brightness                                                         49
# contrast                                                           70
# autoexposure                                                        1
# exposuretime                                                   123.08
# source_shape                                          (1024, 1280, 3)
# source_size_y                                                    1024
# source_size_x                                                    1280
# source_size_band                                                    3
# resolution_x                                                 0.429688
# resolution_y                                                 0.429688
# upleftx                                                       55596.5
# uplefty                                                       84644.5
# affine_transform    (55596.5, 0.4296875, 0.0, 84644.5, 0.0, -0.429...
# Name: 746, dtype: object
# png                 images/ScanImage_AR2_6_41_Ablation_EndPattern_...
# meta                images/ScanImage_AR2_6_41_Ablation_EndPattern_...
# rotation                                                            0
# center_x                                                      53199.5
# center_y                                                        66292
# size_x                                                            550
# size_y                                                            440
# brightness                                                         49
# contrast                                                           70
# autoexposure                                                        1
# exposuretime                                                   123.08
# source_shape                                          (1024, 1280, 3)
# source_size_y                                                    1024
# source_size_x                                                    1280
# source_size_band                                                    3
# resolution_x                                                 0.429688
# resolution_y                                                 0.429688
# upleftx                                                       52924.5
# uplefty                                                         66072
# affine_transform    (52924.5, 0.4296875, 0.0, 66072.0, 0.0, -0.429...
# Name: 747, dtype: object
# png                 images/ScanImage_W235_1_10_Ablation_EndPattern...
# meta                images/ScanImage_W235_1_10_Ablation_EndPattern...
# rotation                                                            0
# center_x                                                        55763
# center_y                                                      40460.5
# size_x                                                            550
# size_y                                                            440
# brightness                                                         49
# contrast                                                           70
# autoexposure                                                        1
# exposuretime                                                   123.08
# source_shape                                          (1024, 1280, 3)
# source_size_y                                                    1024
# source_size_x                                                    1280
# source_size_band                                                    3
# resolution_x                                                 0.429688
# resolution_y                                                 0.429688
# upleftx                                                         55488
# uplefty                                                       40240.5
# affine_transform    (55488.0, 0.4296875, 0.0, 40240.5, 0.0, -0.429...
# Name: 748, dtype: object
# png                 images/ScanImage_AR2_10_13_Ablation_EndPattern...
# meta                images/ScanImage_AR2_10_13_Ablation_EndPattern...
# rotation                                                            0
# center_x                                                        43072
# center_y                                                      67838.5
# size_x                                                            550
# size_y                                                            440
# brightness                                                         49
# contrast                                                           70
# autoexposure                                                        1
# exposuretime                                                   123.08
# source_shape                                          (1024, 1280, 3)
# source_size_y                                                    1024
# source_size_x                                                    1280
# source_size_band                                                    3
# resolution_x                                                 0.429688
# resolution_y                                                 0.429688
# upleftx                                                         42797
# uplefty                                                       67618.5
# affine_transform    (42797.0, 0.4296875, 0.0, 67618.5, 0.0, -0.429...
# Name: 749, dtype: object
# png                 images/ScanImage_KT_11_14_Ablation_EndPattern_...
# meta                images/ScanImage_KT_11_14_Ablation_EndPattern_...
# rotation                                                            0
# center_x                                                            3
# center_y                                                      28327.5
# size_x                                                            550
# size_y                                                            440
# brightness                                                         49
# contrast                                                           70
# autoexposure                                                        1
# exposuretime                                                   123.08
# source_shape                                          (1024, 1280, 3)
# source_size_y                                                    1024
# source_size_x                                                    1280
# source_size_band                                                    3
# resolution_x                                                 0.429688
# resolution_y                                                 0.429688
# upleftx                                                          -272
# uplefty                                                       28107.5
# affine_transform    (-272.0, 0.4296875, 0.0, 28107.5, 0.0, -0.4296...
# Name: 750, dtype: object
# png                 images/ScanImage_AR2_6_32_Ablation_EndPattern_...
# meta                images/ScanImage_AR2_6_32_Ablation_EndPattern_...
# rotation                                                            0
# center_x                                                        53074
# center_y                                                        66338
# size_x                                                            550
# size_y                                                            440
# brightness                                                         49
# contrast                                                           70
# autoexposure                                                        1
# exposuretime                                                   123.08
# source_shape                                          (1024, 1280, 3)
# source_size_y                                                    1024
# source_size_x                                                    1280
# source_size_band                                                    3
# resolution_x                                                 0.429688
# resolution_y                                                 0.429688
# upleftx                                                         52799
# uplefty                                                         66118
# affine_transform    (52799.0, 0.4296875, 0.0, 66118.0, 0.0, -0.429...
# Name: 751, dtype: object
# png                 images/ScanImage_KT_04_7_Ablation_EndPattern_1...
# meta                images/ScanImage_KT_04_7_Ablation_EndPattern_1...
# rotation                                                            0
# center_x                                                        17641
# center_y                                                        39113
# size_x                                                            550
# size_y                                                            440
# brightness                                                         49
# contrast                                                           70
# autoexposure                                                        1
# exposuretime                                                   123.08
# source_shape                                          (1024, 1280, 3)
# source_size_y                                                    1024
# source_size_x                                                    1280
# source_size_band                                                    3
# resolution_x                                                 0.429688
# resolution_y                                                 0.429688
# upleftx                                                         17366
# uplefty                                                         38893
# affine_transform    (17366.0, 0.4296875, 0.0, 38893.0, 0.0, -0.429...
# Name: 752, dtype: object
# png                 images/ScanImage_AR2_6_56_Ablation_EndPattern_...
# meta                images/ScanImage_AR2_6_56_Ablation_EndPattern_...
# rotation                                                            0
# center_x                                                      54425.5
# center_y                                                      68147.5
# size_x                                                            550
# size_y                                                            440
# brightness                                                         49
# contrast                                                           70
# autoexposure                                                        1
# exposuretime                                                   123.08
# source_shape                                          (1024, 1280, 3)
# source_size_y                                                    1024
# source_size_x                                                    1280
# source_size_band                                                    3
# resolution_x                                                 0.429688
# resolution_y                                                 0.429688
# upleftx                                                       54150.5
# uplefty                                                       67927.5
# affine_transform    (54150.5, 0.4296875, 0.0, 67927.5, 0.0, -0.429...
# Name: 753, dtype: object
# png                 images/ScanImage_W235_9_51_Ablation_EndPattern...
# meta                images/ScanImage_W235_9_51_Ablation_EndPattern...
# rotation                                                            0
# center_x                                                      51039.5
# center_y                                                         4127
# size_x                                                            550
# size_y                                                            440
# brightness                                                         49
# contrast                                                           70
# autoexposure                                                        1
# exposuretime                                                   123.08
# source_shape                                          (1024, 1280, 3)
# source_size_y                                                    1024
# source_size_x                                                    1280
# source_size_band                                                    3
# resolution_x                                                 0.429688
# resolution_y                                                 0.429688
# upleftx                                                       50764.5
# uplefty                                                          3907
# affine_transform    (50764.5, 0.4296875, 0.0, 3907.0, 0.0, -0.4296...
# Name: 754, dtype: object
# png                 images/ScanImage_KT_04_10_Ablation_EndPattern_...
# meta                images/ScanImage_KT_04_10_Ablation_EndPattern_...
# rotation                                                            0
# center_x                                                      17950.5
# center_y                                                        39028
# size_x                                                            550
# size_y                                                            440
# brightness                                                         49
# contrast                                                           70
# autoexposure                                                        1
# exposuretime                                                   123.08
# source_shape                                          (1024, 1280, 3)
# source_size_y                                                    1024
# source_size_x                                                    1280
# source_size_band                                                    3
# resolution_x                                                 0.429688
# resolution_y                                                 0.429688
# upleftx                                                       17675.5
# uplefty                                                         38808
# affine_transform    (17675.5, 0.4296875, 0.0, 38808.0, 0.0, -0.429...
# Name: 755, dtype: object
# png                 images/ScanImage_W235_4_23_Ablation_EndPattern...
# meta                images/ScanImage_W235_4_23_Ablation_EndPattern...
# rotation                                                            0
# center_x                                                        42747
# center_y                                                        36171
# size_x                                                            550
# size_y                                                            440
# brightness                                                         49
# contrast                                                           70
# autoexposure                                                        1
# exposuretime                                                   123.08
# source_shape                                          (1024, 1280, 3)
# source_size_y                                                    1024
# source_size_x                                                    1280
# source_size_band                                                    3
# resolution_x                                                 0.429688
# resolution_y                                                 0.429688
# upleftx                                                         42472
# uplefty                                                         35951
# affine_transform    (42472.0, 0.4296875, 0.0, 35951.0, 0.0, -0.429...
# Name: 756, dtype: object
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
#        ...
# 752    None
# 753    None
# 754    None
# 755    None
# 756    None
# Length: 757, dtype: object
